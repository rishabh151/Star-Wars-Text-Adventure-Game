# %%
from sys import exit
import random

def intro_stage():
    """
    DocString:
    
    A) Introduction:
    This is the introduction stage. 
    The game is set in the starwars universe they are given an opportunity to
    save the galaxy. To do so they need to rise to the level of a master Jedi
    over 4 stages and if they pass these stages they get to battle the big boss
    the evil emperor.......
    
    Round 1: Basic Training -- learning teamwork
    Round 2: Mission 1 - guard duty for a quick supply run 
    Round 3: Mission 2 - free the revolutionaries from the enemy barrack
    Round 4: Final mission - battle with the evil emperor 
    
    B) Known Bugs and/or Errors:
    None.
    
    """    
    print("""
     ⠀⠀⠀⠀⠀⣀⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⠀⢀⣤⣤⣤⣤⣤⣤⣤⠀⠀⠀⠀⢠⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⣼⣿⣿⣿⣿⣿⣿⣿⣇⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣟⠛⠛⠛⠛⠛⣿⣿⣿⣿⡟⠛⠛⠛⠛⠛⢠⣿⣿⣿⣿⠿⣿⣿⣿⣿⡀⠀⠀⢸⣿⣿⣿⣿⡏⠉⠉⢉⣿⣿⣿⣿⡇⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀  ⠙⢿⣿⣿⣿⣿⣷⡀⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⣾⣿⣿⣿⡟⠀⢻⣿⣿⣿⣧⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀⠀
⣤⣤⣤⣤⣤⣤⣤⣤⣤⣬⣿⣿⣿⣿⣿⣷⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣤⣤⣤⣤⣤⣤
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠏⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⢀⣿⣿⣿⣿⡿⠿⠿⠿⠿⣿⣿⣿⣿⡀⢸⣿⣿⣿⣿⡇⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠟⠛⠁⠀⠀⠀⠀⠿⠿⠿⠿⠇⠀⠀⠀⠸⠿⠿⠿⠟⠀⠀⠀⠀⠀⠻⠿⠿⠿⠇⠸⠿⠿⠿⠿⠇⠀⠀⠙⠛⠿⠿⠿⠿⠿⠿⠿⠿
⢻⣿⣿⣿⣿⡄⢠⣿⣿⣿⣿⣿⡆⠀⣾⣿⣿⣿⡟⠀⢀⣾⣿⣿⣿⣿⣿⣿⡄⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣦⣄⠀⠀⠀⠀⣠⣶⣶⣿⣿⣿⣿⣿⣿⣿⣿
⠈⣿⣿⣿⣿⣷⣼⣿⣿⣿⣿⣿⣿⣸⣿⣿⣿⣿⠁⠀⣼⣿⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⣿⣿⣿⣿⣿⠿⠿⢿⣿⣿⣿⣿⣇⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⢠⣿⣿⣿⣿⠏⢿⣿⣿⣿⣇⠀⠀⠀⣿⣿⣿⣿⣿⣀⣀⣀⣼⣿⣿⣿⡟⠀⠀⢹⣿⣿⣿⣿⣿⣄⠀⠀⠀⠀⠀
⠀⠀⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⠀⣾⣿⣿⣿⣟⣀⣸⣿⣿⣿⣿⡀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⠁⠀⠀⠀⠙⢿⣿⣿⣿⣿⣧⠀⠀⠀⠀
⠀⠀⠘⣿⣿⣿⣿⣿⣿⠋⣿⣿⣿⣿⣿⣿⠇⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⠀⠀⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣶⣶⣶⣶⣶⣶⣾⣿⣿⣿⣿⣿⠇⠀⠀⠀
⠀⠀⠀⢻⣿⣿⣿⣿⡏⠀⢹⣿⣿⣿⣿⡟⠀⢀⣿⣿⣿⣿⡟⠛⠛⠛⠛⣿⣿⣿⣿⡆⠀⣿⣿⣿⣿⣿⠀⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀
⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠉⠉⠉⠉⠁⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠀⠉⠉⠉⠉⠉⠀⠀⠀⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠁⠀⠀⠀⠀⠀    
    """)
    
    print("""
In a galaxy far far away!!!! A new hero starts their journey....
        
The evil empire has started taking over the galaxy. It all started 25
years ago when the one who was supposed to save the galaxy turned to
the dark side... 
        
Young padawan you are our new hope. You will have to go through a rigorous
training to acheive your potential. 
    """)
    
    
    print("*"*80)
    
    #ask user if they want to play the game....
    user_input = input("Are you ready to start your journey?(Yes/No): \n")
    
    input_chance = 3 #total number of chances the user gets 
    
    while input_chance > 0:
    
        if user_input.lower() == "yes":
            print("Go to training area")
            print("*"*80)
            training()
            break

        elif user_input.lower() == "no":
            print("You are running away from your responsibility!!! You Failed the Galaxy!!")
            print("*"*80)
            break

        else:
            print("""
Something went wrong!!! please enter yes or no
                """)
            print("*"*80)
        
        user_input = input("Are you ready to start your journey?(Yes/No): \n")
        
        input_chance -= 1 
        
        
def training():
    
    print("""
Now that you have decided to embrace your destiny let us start your training.
You need to complete atlease one of these trainings to go for your fist mission
    
You have the following trainings to complete:
    1) Obstacle course
    2) Light Saber Training
    
    """)
    
    print("*"*80)
    
    # asks user to choose one of the trainings or giveup
    user_input = input("""
If you want to start training then choose any one of the trainings 
or giveup: \n
    """)
    
    print("*"*80)
    
    chance = 1
    
    while chance > 0:
        
        if "1" in user_input.lower() or "obstacle" in user_input.lower() or\
        "course" in user_input.lower():
            print("Welcome to the obstacle course")
            
            laps = 2
            
            obstacle_list = ['Wall', 'Pit', 'Droids']
            
            print("*"*80)
            
            choice = input("Are you ready (yes/no): \n")
            
            if choice.lower() == "yes":
               
                while laps > 0:
                    obstacle = random.choice(obstacle_list) #chooses an obstacle at random from the obstacle list
                    
                    if obstacle == obstacle_list[0]:               
                        print("""
While running you suddenly find a wall in front of you what will you do?                   
                        """)
                        
                        options = ["1. Use force to jump",
                                   "2. Break the wall"]      #list of moves that the user can make
                        
                        print(f"""
Here are your options:
    {options}                       
                               """)
                       
                        print("*"*80)
                        
                        choice_2 = input("please mention your choice: ") #User input for the move....
                        
                        if "1" in choice_2.lower() or "jump" in choice_2.lower()\
                                or "force" in choice_2.lower():
                            
                            print("You have mastered the use of force!! obstacle cleared")
                            print("*"*80)
                            
                        elif "2" in choice_2.lower() or "break" in choice_2.lower():
                            
                            print("you chose violence that's not the Jedi way! be careful")
                            print("*"*80)
                            
                        else:
                            print("you failed this obstacle! go back to begining")
                            print("*"*80)
                            training()
                            break
                    
                    elif obstacle == obstacle_list[1]:               
                        print("""
While running you suddenly find a pit in front of you...... 
                        """)
                        
                        input("press enter to jump over the pit \n")
                        
                        print("you have successfully crossed this obstacle")
                        print("*"*80)
                        
                    elif obstacle == obstacle_list[2]:               
                        print("""
While running you suddenly find two droids with hostages in front of you......
If you choose violence you there is no way to save the hostages (that will not impact your results)
                        """)
                        
                        #list of moves player can choose from
                        options_1 = ["1. use force to disable the droids",
                                     "2. attack the droids with everything you have"]                         
                        print(f"""
Here are your options:
    {options_1}                       
                        """)
                        
                        choice_1 = input("what will you do: ")
                        
                        if "1" in choice_1.lower() or "disable" in choice_1.lower() or "force" in choice_1.lower():
                            
                            print("You have mastered the use of force!! By using force you disabled the droids")
                            
                            
                        elif "2" in choice_1.lower() or "attack" in choice_1.lower():
                            
                            print("A Jedi uses violence as the last resort! be careful of the dark side")
                            
                            
                        else:
                            fail()
                            
                    laps -= 1
                    
                print("Congratulations!! you have cleared the obstacle course")
                print("*"*80)
                
            elif choice.lower() == "no":
                print("you are not yet ready to be a Jedi!! Come back when you are ready")
                break
                
            else:
                print("next time select yes or no")
                print("*"*80)
                training()
                
                
        elif "2" in user_input.lower() or "light" in user_input.lower() or\
        "saber" in user_input.lower():
            
            #list of moves user can learn
            move_list = ["Hurricane", "Defence Cut", "Dragon's Tail", "Tempest"]
            
            print(f"""
You have choosen to learn light saber moves. 
Here is a list of moves, you can learn any 2:
            {move_list}
            """)
            print("*"*80)
            
            moves_learnt = 2
            
            while moves_learnt > 0:
            
                select_move = input("Select the move you want to learn")

                if select_move.title() == move_list[0]:

                    print("""
Just like a real hurricane, the correct conditions must exist for this to occur
-- and those conditions can be quite rare. When the Hurricane does work, it is
spectacular … and devastating.

    1. Start in a "Wrath" stance with the blade behind the back at an angle.

    2. Deliver a powerful descending cut at the opponent's shoulder while moving
       at a forward angle with a passing step.

    3. If the opponent moves out of distance, let go of the blade with the backhand.

    4. Sweep the blade up and behind the head while supinating the wrist and 
       rotating the body so that the blade is pointed at the opponent. Make sure
       that the blade is pointed at the opponent so that they do not attempt
       to move forward and strike.

    5. Jump in the air and forward to surprise the opponent and cause them to react.

    6. While landing, sweep the blade in front of the body in a horizontal cut at the opponent.

    7. Bring the blade back up in an ascending strike to the opponent.

    8. Grab the hilt with the backhand and bring the saber back into a hanging guard to protect the body.

    9. Take a bow for executing such a complex move.                
                    """)
                    print("*"*80)
                    
                elif select_move.title() == move_list[1]:

                    print("""
Created by a man nicknamed the Bonebreaker, a seventh-level swordsman of the 
Western Circle of Swordfighters, in order to defeat his opponent. A circumstantial
move to be used against opponents who like to riposte with a slash to the shoulders.

    1. Start in "Defensive" stance: The point of your saber is forward
       and facing your opponent, and angled at their chest. The arms are extended
       forward but with a slight bend at the elbows. Hips are square to the opponent
       and shoulders are relaxed. The legs are slightly bent with your dominan
       t foot forward, the same side as your dominant hand. Both feet are angled
       outward as if you are walking a tightrope.

    2. Make a full circle behind the head to deliver a descending cut at an angle
       at the opponent's shoulder.

    3. When the blade is moving in front of you, make a passing step forward.

    4. If the opponent defends the attack by moving out of distance or parries
       the blow and attempts to deliver a riposte with a shoulder cut, quickly
       raise the blade high at an angle so that the opponent's blade is deflected down.

    5. Make a side step to the opponent's vulnerable side (the opposite side of
       their weapon) while delivering another full circle cut to the opponent's
       head. Make sure to only side-step when the blade is in front of you and
       can defend a blow.

    6. As the blade is about to land, pivot the back foot so that the body is
       at an oblique angle to the opponent, further distancing yourself from a
       counterattack.

    7. Raise the blade again in a hanging guard to ward against any other blows.
                    """)
                    print("*"*80)
                    
                elif select_move.title() == move_list[2]:

                    print("""
Most often people think that a dragon's most dangerous attack involves its 
fiery breath. But that ignores a dragon's secret weapon.

    1. Start in a "Falcon" stance with the hands holding the blade high and 
       near the shoulder of the back foot.

    2. Release the forward hand and cast the blade out with the back hand in a
       descending cut to your opponent's shoulder while stepping forward at an
       angle. The goal is to cause the opponent to want to defend the attack 
       by moving their blade up or distracting them.

    3. As the opponent defends, quickly sweep the blade down and aim at the opponent's
       legs, making sure that the body is still defended by moving out of distance.

    4. Pivot the leg and bring the blade up into a hanging guard to ward against
       any counter blows.
                    """)
                    print("*"*80)
                    
                elif select_move.title() == move_list[3]:

                    print("""
The blade moves in wide, sweeping motions aggressively in front of the opponent
-- like a tempest! -- to create openings for your attacks.

    1. Start in a "Resting" stance, with the point of the blade off to the side
       of the back foot. This stance is also known as "Iron Door" or "Iron Gate."

    2. Move the blade in an arc to the other side of your body, while moving at
       a slight angle away from the blade with a passing step, making sure that
       the body is defended from any incoming blows.

    3. If the opponent takes the bait and follows the blade, then attack with
       a full circle cut to the shoulder by bringing the blade behind the head
       and cutting down at a descending angle. Otherwise, continue moving the 
       blade from side to side while stepping at a slight angle toward your 
       opponent until they react. Make sure not to do this too often or at a 
       consistent rhythm, because your opponent will be able to predict the movements.

    4. When the blade arcs across, it can also be used to beat away and displace
       the opponent's blade to create an opening.

    5. During the cut, pivot the back foot so that the body moves away from the
       target at an oblique angle.
                    """)
                    print("*"*80)
                    
                else:
                    print("Please select a move from the list! You are not yet cleared to learn other moves")
                    print(f"{move_list}")
                    print("*"*80)
                    
                print(f"""
Congratulations!!! You have mastered {select_move.title()}
You choose to learn one more skill... please select a different skill:
    {move_list}
""")
                print("*"*80)
            
                moves_learnt -= 1
            print("Congratulations you have mastered the light saber.....")
            break
            
        elif "give" in user_input.lower():
            fail()
            quit()

            
        else:
            print("You need to finish the listed trainings fist...!!")
            user_input = input("""
If you want to start training then choose any one of the trainings 
or giveup: \n
    """)
            
        chance -= 1  
    
    user_input_2 = input("""
    Are you ready for your first mission (yes/no): 
    """)
    print("*"*80)
    
    if user_input_2 == "yes":
        guard_duty()
    else:
        training()
        
def guard_duty():
    print("""
You are required defend the rebel command training.. you are equiped with one
light saber, one blaster and help of force.....
    
Attention!!!!! First wave of enemies are coming.....
    """)
    print("*"*80)
    print("""
    ⠀⠀⠀⠀⠀⢀⡶⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣾⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⣼⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⣰⡏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢰⡟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⢠⣿⣄⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⢀⣾⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⣼⠿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⣼⡏⠀⠙⣿⣿⣿⣷⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢀⣤⡟⠀⣠⣾⣿⣿⣿⣿⣿⣆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣇⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠈⠉⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠈⠛⠛⠿⠟⢋⣿⣿⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⠇⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⢿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢸⣿⣿⣿⠏⠀⠻⣿⣿⣇⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⣿⣿⣿⠇⠀⠀⠀⢿⣿⣿⣆⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⣿⣿⡇⠀⠀⠀⠀⠀⢻⣿⣿⣧⡀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⣿⣿⣷⠀⠀⠀⠀⠀⠀⠈⢻⣿⣷⡀⠀⠀⠀
⠀⠀⠀⠀⠀⢸⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠙⢿⣧⡀⠀⠀
⠀⠀⠀⠀⠀⢸⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣷⣄⠀
⠀⠀⠀⠀⣠⣾⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣿⣿⡆
⠀⠀ ⠘⠛⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠛⠁
    """)
    
    army = ["Storm Troopers", "Walkers", "Artilery"]
    weapons = ["Light Saber", "Blaster", "Force"]
    remaining_weapons = []
    remaining_weapons_1 = []
    
    #iterates through each item in the army list
    for i in army: 
        
        print(f"""
This wave has {i}
        """)
        
        #wave 1
        if i == "Storm Troopers": 
            print(f"""
You have following weapons remaining:
    {weapons}
            """)
            
            print("*"*80)
            
            selected_weapon = input("select a weapon: ")
            
            if selected_weapon.title() == weapons[0]:
                print(f"""
You selected a {selected_weapon.title()}.....
You faught breavely.. Your light saber skills are exemplary!! mission cleared
                """)
                print("*"*80)
                
                #remove the selected weapon from the weapons list and adds to the remaining weapons
                for weapon in weapons:
                    if selected_weapon.title() != weapon:
                        remaining_weapons.append(weapon)
            
            elif selected_weapon.title() == weapons[1]:
                print(f"""
You selected a {selected_weapon.title()}.....
You chose the quick way.. to defeat this wave!! Blaster was exactly what you needed for this wave 
                """)
                print("*"*80)
                
                #remove the selected weapon from the weapons list and adds to the remaining weapons
                for weapon in weapons:
                    if selected_weapon.title() != weapon:
                        remaining_weapons.append(weapon)
                        
            elif selected_weapon.title() == weapons[2]:
                print(f"""
You selected a {selected_weapon.title()}.....
You chose to use force... You are on the way to become a better Jedi master
                """)
                print("*"*80)
                
                #force is used which is not a weapon but a skill so no loss of weapons
                for weapon in weapons:
                    if selected_weapon.title() == weapon:
                        remaining_weapons.extend(weapons)
            
            else:
                fail()
                

        
        elif i == "Walkers":
            print(f"""
You have following weapons remaining:
    {remaining_weapons}
            """)
            print("*"*80)
            
            selected_weapon_1 = input("select a weapon: ")
            
            if selected_weapon_1.title() == weapons[0]:
                print(f"""
You selected a {selected_weapon_1.title()}.....
It takes a highly skilled Jedi to takedown a Walker with a light saber
                """)
                print("*"*80)
                
                #remove the selected weapon from the weapons list and add it unused weapons to remaining weapons
                for weapon in remaining_weapons:
                    if selected_weapon.title() != weapon:
                        remaining_weapons_1.append(weapon)
            
            elif selected_weapon_1.title() == weapons[1]:
                print(f"""
You selected a {selected_weapon_1.title()}.....
You took heavy damage...blaster is weak against walkers 
                """)
                print("*"*80)
                
                #remove the selected weapon from the weapons list
                for weapon in remaining_weapons:
                    if selected_weapon_1.title() != weapon:
                        remaining_weapons_1.append(weapon)
                        
            elif selected_weapon_1.title() == weapons[2]:
                print(f"""
You selected a {selected_weapon.title()}.....
Force is the strongest weapon in your arsenal... 
                """)
                print("*"*80)
                
                #force is used which is not a weapon but a skill so no loss of weapons
                for weapon in remaining_weapons:
                    if selected_weapon_1.title() == weapon:
                        remaining_weapons_1.extend(remaining_weapons)

            else:
                fail()
                
        elif i == "Artilery":
            print(f"""
You have following weapons remaining:
    {remaining_weapons_1}
            """)
            
            selected_weapon_2 = input("select a weapon: ")
            
            if selected_weapon_2.title() == weapons[2]:
                print(f"""
You selected a {selected_weapon_2.title()}.....
You chose the jedi way.. to defet this wave
                """)
                print("*"*80)
            
            else:
                fail()
                
        
        else:
            print("Enemy did not come today!! you live to fight another day")
            print("*"*80)
        
    free_hostage()
        
def free_hostage():
    
        print("""
Ah!! Young Jedi... it is good to see you...
Your reputation preseeds you. Though you successfully defended your command center
some of your counterparts failed.. now its up to you to save them
        """)
        print("*"*80)
        
        input("press enter to continue \n")
        
        print("""
You go to the enemy camp and see that it is heavily guarded. You have to choose
if you want to go use stealth or a frontal attack to save fellow Jedi....
May the force be with you...
        """)
        print("*"*80)
        
        user_choice = input("Select a strategy... (Stealth/Frontal Attack): \n")
        
        if "stealth" in user_choice.lower():
            
            print("""
A very good strategy...
Using stealth you entered the enemy base undetected. You quietly went up to the
holding area... You used force to free all the captured Jedi and resistance soilders
            """)
            print("*"*80)
            
            
            final_stage()
       
        elif "frontal" in user_choice.lower() or "attack" in user_choice.lower():
            
            print("""
You completed the mission but you lost more than half of your fellow Jedi collateral
damage was huge...... 

You entered the enemy base and started killing anyone you see in front of you and 
with the help of your light saber you break the holding area... and free all the 
captured Jedi and resistance soilders...

Due to the cummosion some guards called for backup... and the during the fight 
with these soilders you loose some of your people....
            
Young Jedi you must control your else... your actions in the previous mission
has shown that you are leaning towards the dark side...
            """)
            print("*"*80)
            
            final_stage()
        
        else:
            fail()

def final_stage():
    
    print("""
Young Jedi!!! The time has come to fulfill your destiny....
We have located Darth Vader and his army.... The allies you rescued in your
previous mission will join you in your fight. They will engage with the imperial
army of Darth Vader... Your mission is to fight and capture Darth Vader....
    
But remember this if you let your emotions take over you will slip to the dark side...
    
May the force be with you
    """)
    print("*"*80)
    
    input("Press enter to continue \n")
    
    print("""
You reach the battle field and see that Darth Vader is overwelming the Jedi army...
But you have an oppotunity to kill darth vader.. if you do so the battle will 
be won but you will loose many of your friends....
choose carefully as the fate of the galaxy depends on you....
    """)
    print("*"*80)
    
    
    final_choice = input("Kill or capture: ")
    
    if final_choice.lower() == "kill":
        print("""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⡀⠀⠀⠀⢀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣤⣶⣾⣿⡉⢤⣍⡓⢶⣶⣦⣤⣉⠒⠤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣿⣿⣿⣿⣷⡀⠙⣿⣷⣌⠻⣿⣿⣿⣶⣌⢳⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣄⠈⢿⣿⡆⠹⣿⣿⣿⣿⣷⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣄⠹⣿⡄⢻⣿⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠿⣿⣿⣷⣽⣷⢸⣿⡿⣿⡿⠿⠿⣆⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡄⠀⠀⠀⠐⠾⢭⣭⡼⠟⠃⣤⡆⠘⢟⢺⣦⡀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⢛⣥⣶⠾⠿⠛⠳⠶⢬⡁⠀⠀⠘⣃⠤⠤⠤⢍⠻⡄⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⡿⣫⣾⡿⢋⣥⣶⣿⠿⢿⣿⣿⣿⠩⠭⢽⣷⡾⢿⣿⣦⢱⡹⡀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⡟⠈⠛⠏⠰⢿⣿⣿⣧⣤⣼⣿⣿⣿⡏⠩⠽⣿⣀⣼⣿⣿⢻⣷⢡⠀⠀⠀
⠀⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⣿⢁⣿⣷⣦⡀⠀⠉⠙⠛⠛⠛⠋⠁⠙⢻⡆⠀⢌⣉⠉⠉⠀⠸⣿⣇⠆⠀⠀
⠀⠀⠀⠀⢀⣾⣿⣿⣿⣿⣿⡇⢸⣿⣿⣿⣿⠷⣄⢠⣶⣾⣿⣿⣿⣿⣿⠁⠀⠀⢿⣿⣿⣿⣷⠈⣿⠸⡀⠀
⠀⠀⠀⠀⣼⣿⣿⣿⣿⣿⣿⠀⣌⡛⠿⣿⣿⠀⠈⢧⢿⣿⡿⠟⠋⠉⣠⣤⣤⣤⣄⠙⢿⣿⠏⣰⣿⡇⢇⠀
⠀⠀⠀⣼⣿⣿⣿⣿⣿⣿⡇⢸⣿⣿⣶⣤⣙⠣⢀⠈⠘⠏⠀⠀⢀⣴⢹⡏⢻⡏⣿⣷⣄⠉⢸⣿⣿⣷⠸⡄
⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⠁⣾⣟⣛⠛⠛⠻⠿⠶⠬⠔⠀⣠⡶⠋⠿⠈⠷⠸⠇⠻⠏⠻⠆⣀⢿⣿⣿⡄⢇
⠀⢰⣿⣿⣿⣿⠿⠿⠛⠋⣰⣿⣿⣿⣿⠿⠿⠿⠒⠒⠂⠀⢨⡤⢶⣶⣶⣶⣶⣶⣶⣶⣶⠆⠃⣀⣿⣿⡇⣸
⢀⣿⣿⠿⠋⣡⣤⣶⣾⣿⣿⣿⡟⠁⠀⣠⣤⣴⣶⣶⣾⣿⣿⣷⡈⢿⣿⣿⣿⣿⠿⠛⣡⣴⣿⣿⣿⣿⠟⠁
⣼⠋⢁⣴⣿⣿⣿⣿⣿⣿⣿⣿⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣎⠻⠟⠋⣠⣴⣿⣿⣿⣿⠿⠋⠁⠀⠀
⢿⣷⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⣴⠀⠻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣠⣾⣿⠿⠿⠟⠋⠁⠀⠀⠀⠀⠀
⠀⠉⠛⠛⠿⠿⠿⢿⣿⣿⣿⣵⣾⣿⣧⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
        
        
        """)
        
        print("""
You decided to kill Darth Vader......
But in doing so you forgot to save your fellow Jedi who could have been saved.
The loss of your friends saddens you.. you feel helpless. The victory seemed 
empty. At this moment you hear a voice.....
        
Young Jedi... This is the weakness of the way of Jedi, Jedi are weak they fail
to save their loved ones..... Come and join the dark side so that you never
have to feel this helpless again... You give in to the dark side..
        
One more Jedi has fallen to the dark side and the empire continues to rule the galaxy....
        """)
        fail()

       
    
    elif final_choice.lower() == "capture": 
        
        print("""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣤⠤⠐⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡌⡦⠊⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⣼⡊⢀⠔⠀⠀⣄⠤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣤⣄⣀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣶⠃⠉⠡⡠⠤⠊⠀⠠⣀⣀⡠⠔⠒⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⣿⢟⠿⠛⠛⠁
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⡇⠀⠀⠀⠀⠑⠶⠖⠊⠁⠀⠀⠀⡀⠀⠀⠀⢀⣠⣤⣤⡀⠀⠀⠀⠀⠀⢀⣠⣤⣶⣿⣿⠟⡱⠁⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣾⣿⡇⠀⢀⡠⠀⠀⠀⠈⠑⢦⣄⣀⣀⣽⣦⣤⣾⣿⠿⠿⠿⣿⡆⠀⠀⢀⠺⣿⣿⣿⣿⡿⠁⡰⠁⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣧⣠⠊⣠⣶⣾⣿⣿⣶⣶⣿⣿⠿⠛⢿⣿⣫⢕⡠⢥⣈⠀⠙⠀⠰⣷⣿⣿⣿⡿⠋⢀⠜⠁⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⢿⣿⣿⣿⣿⣰⣿⣿⠿⣛⡛⢛⣿⣿⣟⢅⠀⠀⢿⣿⠕⢺⣿⡇⠩⠓⠂⢀⠛⠛⠋⢁⣠⠞⠁⠀⠀⠀⠀⠀⠀⠀⠀
⠘⢶⡶⢶⣶⣦⣤⣤⣤⣤⣤⣀⣀⣀⣀⡀⠀⠘⣿⣿⣿⠟⠁⡡⣒⣬⢭⢠⠝⢿⡡⠂⠀⠈⠻⣯⣖⣒⣺⡭⠂⢀⠈⣶⣶⣾⠟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠙⠳⣌⡛⢿⣿⣿⣿⣿⣿⣿⣿⣿⣻⣵⣨⣿⣿⡏⢀⠪⠎⠙⠿⣋⠴⡃⢸⣷⣤⣶⡾⠋⠈⠻⣶⣶⣶⣷⣶⣷⣿⣟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠈⠛⢦⣌⡙⠛⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⠩⠭⡭⠴⠊⢀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣿⣿⣿⣿⣿⡇⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠈⠙⠓⠦⣄⡉⠛⠛⠻⢿⣿⣿⣿⣷⡀⠀⠀⠀⠀⢀⣰⠋⠀⠀⠀⠀⠀⣀⣰⠤⣳⣿⣿⣿⣿⣟⠑⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠓⠒⠒⠶⢺⣿⣿⣿⣿⣦⣄⣀⣴⣿⣯⣤⣔⠒⠚⣒⣉⣉⣴⣾⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠹⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣭⣉⣉⣤⣿⣿⣿⣿⣿⣿⡿⢀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⡁⡆⠙⢶⣀⠀⢀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣴⣶⣾⣿⣟⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⢛⣩⣴⣿⠇⡇⠸⡆⠙⢷⣄⠻⣿⣦⡄⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣼⣿⣿⣿⣿⣿⣿⣿⣎⢻⣿⣿⣿⣿⣿⣿⣿⣭⣭⣭⣵⣶⣾⣿⣿⣿⠟⢰⢣⠀⠈⠀⠀⠙⢷⡎⠙⣿⣦⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣼⣿⣿⣿⣿⣿⣿⣿⣿⡟⣿⡆⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠟⠛⠋⠁⢀⠇⢸⡇⠀⠀⠀⠀⠈⠁⠀⢸⣿⡆⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡜⡿⡘⣿⣿⣿⣿⣿⣶⣶⣤⣤⣤⣤⣤⣤⣤⣴⡎⠖⢹⡇⠀⠀⠀⠀⠀⠀⠀⠀⣿⣷⡄⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⡀⠘⢿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠛⠋⡟⠀⠀⣸⣷⣀⣤⣀⣀⣀⣤⣤⣾⣿⣿⣿⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣭⣓⡲⠬⢭⣙⡛⠿⣿⣿⣶⣦⣀⠀⡜⠀⠀⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣭⣛⣓⠶⠦⠥⣀⠙⠋⠉⠉⠻⣄⣀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣆⠐⣦⣠⣷⠊⠁⠀⠀⡭⠙⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⠀
⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⢉⣛⡛⢻⡗⠂⠀⢀⣷⣄⠈⢆⠉⠙⠻⢿⣿⣿⣿⣿⣿⠇⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠘⣿⣿⡟⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡟⣉⢁⣴⣿⣿⣿⣾⡇⢀⣀⣼⡿⣿⣷⡌⢻⣦⡀⠀⠈⠙⠛⠿⠏⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠙⢿⣿⡄⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠛⠛⠛⢯⡉⠉⠉⠉⠉⠛⢼⣿⠿⠿⠦⡙⣿⡆⢹⣷⣤⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠿⠄⠈⠻⠿⠿⠿⠿⠿⠿⠛⠛⠿⠛⠉⠁⠀⠀⠀⠀⠀⠀⠻⠿⠿⠿⠿⠟⠉⠀⠀⠤⠴⠶⠌⠿⠘⠿⠿⠿⠿⠶⠤⠀⠀⠀⠀        
        
        
        """)
        
        print("""
You decided to capture Darth Vader...
        
To do that you will need the help of other Jedi.... You enter the battle field
fight off the enemy army... You turn the tide of the battle....
        
Darth Vader is on the run... but he is cut off by other Jedi who you saved..
After a fierce battle you capture him...
        
Back in the Jedi Council Darth Vader is interrogated who reveal the location
of the emperor...
        
The galaxy is saved for now but we still need to defeat the Emperor!!!!
        
Keep up your training as you will need it in the upcoming battles 
        """)
        
    else:
        fail()
        
def fail():
    print("You failed to save the Galaxy!!")
    print("Game Over")
    exit()


intro_stage()
# Out:
#      ⠀⠀⠀⠀⠀⣀⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⠀⢀⣤⣤⣤⣤⣤⣤⣤⠀⠀⠀⠀⢠⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⣼⣿⣿⣿⣿⣿⣿⣿⣇⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣟⠛⠛⠛⠛⠛⣿⣿⣿⣿⡟⠛⠛⠛⠛⠛⢠⣿⣿⣿⣿⠿⣿⣿⣿⣿⡀⠀⠀⢸⣿⣿⣿⣿⡏⠉⠉⢉⣿⣿⣿⣿⡇⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀  ⠙⢿⣿⣿⣿⣿⣷⡀⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⣾⣿⣿⣿⡟⠀⢻⣿⣿⣿⣧⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀⠀
# ⣤⣤⣤⣤⣤⣤⣤⣤⣤⣬⣿⣿⣿⣿⣿⣷⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣤⣤⣤⣤⣤⣤
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠏⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⢀⣿⣿⣿⣿⡿⠿⠿⠿⠿⣿⣿⣿⣿⡀⢸⣿⣿⣿⣿⡇⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠟⠛⠁⠀⠀⠀⠀⠿⠿⠿⠿⠇⠀⠀⠀⠸⠿⠿⠿⠟⠀⠀⠀⠀⠀⠻⠿⠿⠿⠇⠸⠿⠿⠿⠿⠇⠀⠀⠙⠛⠿⠿⠿⠿⠿⠿⠿⠿
# ⢻⣿⣿⣿⣿⡄⢠⣿⣿⣿⣿⣿⡆⠀⣾⣿⣿⣿⡟⠀⢀⣾⣿⣿⣿⣿⣿⣿⡄⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣦⣄⠀⠀⠀⠀⣠⣶⣶⣿⣿⣿⣿⣿⣿⣿⣿
# ⠈⣿⣿⣿⣿⣷⣼⣿⣿⣿⣿⣿⣿⣸⣿⣿⣿⣿⠁⠀⣼⣿⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⣿⣿⣿⣿⣿⠿⠿⢿⣿⣿⣿⣿⣇⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⢠⣿⣿⣿⣿⠏⢿⣿⣿⣿⣇⠀⠀⠀⣿⣿⣿⣿⣿⣀⣀⣀⣼⣿⣿⣿⡟⠀⠀⢹⣿⣿⣿⣿⣿⣄⠀⠀⠀⠀⠀
# ⠀⠀⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⠀⣾⣿⣿⣿⣟⣀⣸⣿⣿⣿⣿⡀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⠁⠀⠀⠀⠙⢿⣿⣿⣿⣿⣧⠀⠀⠀⠀
# ⠀⠀⠘⣿⣿⣿⣿⣿⣿⠋⣿⣿⣿⣿⣿⣿⠇⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⠀⠀⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣶⣶⣶⣶⣶⣶⣾⣿⣿⣿⣿⣿⠇⠀⠀⠀
# ⠀⠀⠀⢻⣿⣿⣿⣿⡏⠀⢹⣿⣿⣿⣿⡟⠀⢀⣿⣿⣿⣿⡟⠛⠛⠛⠛⣿⣿⣿⣿⡆⠀⣿⣿⣿⣿⣿⠀⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀
# ⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠉⠉⠉⠉⠁⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠀⠉⠉⠉⠉⠉⠀⠀⠀⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠁⠀⠀⠀⠀⠀
#
#
# In a galaxy far far away!!!! A new hero starts their journey....
#
# ...
